# %%
#QUESTION 6

import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Define the objective function coefficients
c = np.array([0.08, 0.1, 0.12])

# Define the constraint coefficients
A = np.array([[2, 3, 1],
              [-1, 0, 0],
              [0, -1, 0],
              [0, 0, -1]])

# Define the constraint right-hand side values
b = np.array([10000, -2000, -1500, -1000])

# Define the variable bounds
x_bounds = (0, None)
y_bounds = (0, None)
z_bounds = (0, None)

# Generate points for plotting the constraints
x = np.linspace(0, 5000, 100)
y = np.linspace(0, 5000, 100)
z = np.linspace(0, 5000, 100)
X, Y = np.meshgrid(x, y)
Z1 = (10000 - 2*X - 3*Y) / 1
Z2 = np.full_like(X, 2000)
Z3 = np.full_like(X, 1500)
Z4 = np.full_like(X, 1000)

# Plot the constraints
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(X, Y, Z1, alpha=0.5)
ax.plot_surface(X, Z2, Y, alpha=0.5)
ax.plot_surface(Z3, X, Y, alpha=0.5)
ax.plot_surface(Z4, X, Y, alpha=0.5)

# Set labels and limits
ax.set_xlabel('x1')
ax.set_ylabel('x2')
ax.set_zlabel('x3')
ax.set_title('Feasible Region')
ax.set_xlim(x_bounds)
ax.set_ylim(y_bounds)
ax.set_zlim(z_bounds)

# Show the plot
plt.show()
